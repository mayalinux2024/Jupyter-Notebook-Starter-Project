# %%
import pandas as pd

data = {
    "Name":["Ali","Sara","John"],
    "Score":[80,95,70]
}

df = pd.DataFrame(data)

df
# Out:
#    Name  Score
# 0   Ali     80
# 1  Sara     95
# 2  John     70

# %%
df.plot.bar(x="Name", y="Score")
# Out:
# <Axes: xlabel='Name'>
